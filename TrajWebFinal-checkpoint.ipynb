# %%
#!pip install tensorflow

# %%
# !pip install --upgrade tensorflow

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Load your satellite trajectory dataset (replace 'your_dataset.csv' with the actual file name)
# Make sure your dataset includes columns like 'initial_velocity', 'launch_angle', etc.
df = pd.read_csv('satellite_trajectory_dataset.csv')

# %%
# Define features (X) and target variable (y)
features = df[['initial_velocity', 'launch_angle', 'atmospheric_conditions']]
target = df['trajectory_optimization']  # Replace 'trajectory_optimization' with the actual target column name

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Build the neural network model
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)  # Output layer
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/50
# 20/20 - 1s - loss: 2600078.2500 - val_loss: 2598875.0000 - 1s/epoch - 73ms/step
# Epoch 2/50
# 20/20 - 0s - loss: 2596879.2500 - val_loss: 2594749.5000 - 115ms/epoch - 6ms/step
# Epoch 3/50
# 20/20 - 0s - loss: 2591567.5000 - val_loss: 2587549.2500 - 113ms/epoch - 6ms/step
# Epoch 4/50
# 20/20 - 0s - loss: 2582422.0000 - val_loss: 2575844.7500 - 116ms/epoch - 6ms/step
# Epoch 5/50
# 20/20 - 0s - loss: 2567950.5000 - val_loss: 2557976.5000 - 113ms/epoch - 6ms/step
# Epoch 6/50
# 20/20 - 0s - loss: 2546603.2500 - val_loss: 2531801.7500 - 116ms/epoch - 6ms/step
# Epoch 7/50
# 20/20 - 0s - loss: 2515569.2500 - val_loss: 2495173.2500 - 103ms/epoch - 5ms/step
# Epoch 8/50
# 20/20 - 0s - loss: 2473247.2500 - val_loss: 2445519.5000 - 111ms/epoch - 6ms/step
# Epoch 9/50
# 20/20 - 0s - loss: 2416645.0000 - val_loss: 2381629.2500 - 114ms/epoch - 6ms/step
# Epoch 10/50
# 20/20 - 0s - loss: 2345119.0000 - val_loss: 2301337.2500 - 112ms/epoch - 6ms/step
# Epoch 11/50
# 20/20 - 0s - loss: 2256612.5000 - val_loss: 2203637.7500 - 118ms/epoch - 6ms/step
# Epoch 12/50
# 20/20 - 0s - loss: 2151480.0000 - val_loss: 2088020.6250 - 130ms/epoch - 7ms/step
# Epoch 13/50
# 20/20 - 0s - loss: 2028111.3750 - val_loss: 1956573.3750 - 116ms/epoch - 6ms/step
# Epoch 14/50
# 20/20 - 0s - loss: 1888042.7500 - val_loss: 1810706.6250 - 185ms/epoch - 9ms/step
# Epoch 15/50
# 20/20 - 0s - loss: 1734666.3750 - val_loss: 1650274.6250 - 198ms/epoch - 10ms/step
# Epoch 16/50
# 20/20 - 0s - loss: 1567471.6250 - val_loss: 1480588.6250 - 115ms/epoch - 6ms/step
# Epoch 17/50
# 20/20 - 0s - loss: 1393196.0000 - val_loss: 1303766.3750 - 125ms/epoch - 6ms/step
# Epoch 18/50
# 20/20 - 0s - loss: 1215912.3750 - val_loss: 1123508.5000 - 188ms/epoch - 9ms/step
# Epoch 19/50
# 20/20 - 0s - loss: 1037652.0000 - val_loss: 949569.1875 - 133ms/epoch - 7ms/step
# Epoch 20/50
# 20/20 - 0s - loss: 867160.6875 - val_loss: 784177.1250 - 157ms/epoch - 8ms/step
# Epoch 21/50
# 20/20 - 0s - loss: 706274.7500 - val_loss: 634004.8750 - 126ms/epoch - 6ms/step
# Epoch 22/50
# 20/20 - 0s - loss: 563506.9375 - val_loss: 498024.5000 - 189ms/epoch - 9ms/step
# Epoch 23/50
# 20/20 - 0s - loss: 437130.8438 - val_loss: 383984.4375 - 125ms/epoch - 6ms/step
# Epoch 24/50
# 20/20 - 0s - loss: 332070.9062 - val_loss: 290877.0938 - 188ms/epoch - 9ms/step
# Epoch 25/50
# 20/20 - 0s - loss: 249054.9219 - val_loss: 216328.2031 - 115ms/epoch - 6ms/step
# Epoch 26/50
# 20/20 - 0s - loss: 184151.2812 - val_loss: 161521.7969 - 153ms/epoch - 8ms/step
# Epoch 27/50
# 20/20 - 0s - loss: 137321.6094 - val_loss: 121754.8750 - 184ms/epoch - 9ms/step
# Epoch 28/50
# 20/20 - 0s - loss: 103763.4844 - val_loss: 95030.3906 - 156ms/epoch - 8ms/step
# Epoch 29/50
# 20/20 - 0s - loss: 81846.4609 - val_loss: 76572.2266 - 132ms/epoch - 7ms/step
# Epoch 30/50
# 20/20 - 0s - loss: 66962.9531 - val_loss: 64529.4766 - 150ms/epoch - 7ms/step
# Epoch 31/50
# 20/20 - 0s - loss: 57433.1367 - val_loss: 56563.6016 - 117ms/epoch - 6ms/step
# Epoch 32/50
# 20/20 - 0s - loss: 51305.3984 - val_loss: 51119.8672 - 179ms/epoch - 9ms/step
# Epoch 33/50
# 20/20 - 0s - loss: 47066.8047 - val_loss: 47598.6445 - 119ms/epoch - 6ms/step
# Epoch 34/50
# 20/20 - 0s - loss: 44406.2930 - val_loss: 44856.3984 - 121ms/epoch - 6ms/step
# Epoch 35/50
# 20/20 - 0s - loss: 42324.2188 - val_loss: 42960.9688 - 164ms/epoch - 8ms/step
# Epoch 36/50
# 20/20 - 0s - loss: 40862.6953 - val_loss: 41446.6367 - 121ms/epoch - 6ms/step
# Epoch 37/50
# 20/20 - 0s - loss: 39662.1641 - val_loss: 40239.5078 - 184ms/epoch - 9ms/step
# Epoch 38/50
# 20/20 - 0s - loss: 38724.8320 - val_loss: 39216.0742 - 198ms/epoch - 10ms/step
# Epoch 39/50
# 20/20 - 0s - loss: 37910.2578 - val_loss: 38365.5156 - 156ms/epoch - 8ms/step
# Epoch 40/50
# 20/20 - 0s - loss: 37206.1602 - val_loss: 37680.6484 - 156ms/epoch - 8ms/step
# Epoch 41/50
# 20/20 - 0s - loss: 36607.4023 - val_loss: 37035.8984 - 146ms/epoch - 7ms/step
# Epoch 42/50
# 20/20 - 0s - loss: 36026.4023 - val_loss: 36515.5391 - 176ms/epoch - 9ms/step
# Epoch 43/50
# 20/20 - 0s - loss: 35536.7070 - val_loss: 36028.5273 - 128ms/epoch - 6ms/step
# Epoch 44/50
# 20/20 - 0s - loss: 35096.1992 - val_loss: 35542.5703 - 167ms/epoch - 8ms/step
# Epoch 45/50
# 20/20 - 0s - loss: 34632.2344 - val_loss: 35121.9570 - 127ms/epoch - 6ms/step
# Epoch 46/50
# 20/20 - 0s - loss: 34211.8203 - val_loss: 34723.0156 - 109ms/epoch - 5ms/step
# Epoch 47/50
# 20/20 - 0s - loss: 33803.5664 - val_loss: 34312.8203 - 104ms/epoch - 5ms/step
# Epoch 48/50
# 20/20 - 0s - loss: 33431.7266 - val_loss: 33926.7734 - 104ms/epoch - 5ms/step
# Epoch 49/50
# 20/20 - 0s - loss: 33068.6797 - val_loss: 33546.0352 - 110ms/epoch - 6ms/step
# Epoch 50/50
# 20/20 - 0s - loss: 32671.8281 - val_loss: 33230.1641 - 103ms/epoch - 5ms/step

# %%
# Evaluate the model on the test set
predictions = model.predict(X_test_scaled)
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error: {mse}')
# Out:
# 7/7 [==============================] - 0s 3ms/step
# Mean Squared Error: 40353.7026922869

# %%
# Visualize results (for simplicity, you can modify this based on your actual data)
import matplotlib.pyplot as plt
plt.scatter(X_test['initial_velocity'], y_test, color='black', label='Actual')
plt.scatter(X_test['initial_velocity'], predictions, color='blue', label='Predicted')
plt.xlabel('Initial Velocity')
plt.ylabel('Optimized Trajectory')
plt.legend()
plt.show()
